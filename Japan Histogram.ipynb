# %% [markdown]
# ### About Dataset
# Collective data of Japan's birth-related statistics from 1899 to 2022. Some data are missing between the years 1944 and 1946 due to records lost during World War II.
#
# For use case and analysis reference, please take a look at this notebook Japan Birth Demographics Analysis
#
# ## Feature Descriptions
#
# * year: The year.
# * birth_total: The total number of births.
# * birth_male: The total number of male births.
# * birth_female: The total number of female births.
# * birth_rate: The birth rate. Equation is birth_total / population_total * 1,000
# * birth_gender_ratio: The birth gender ratio. Equation is birth_male / birth_female * 1,000
# * total_fertility_rate: The average number of children that are born to a woman over her lifetime.
# * population_total: The total population.
# * population_male: The total male population.
# * population_female: The total female population.
# * infant_death_total: The total infant deaths.
# * infant_death_male: The total male infant deaths.
# * infant_death_female: The total female infant deaths.
# * infant_death_unknown_gender: The total unknown gender infant deaths.
# * infant_death_rate: The infant death rate. Equation is infant_death_total / birth_total* 1,000
# * infant_death_gender_ratio: The infant death gender ratio. Equation is infant_death_male / infant_death_female * 1,000
# * infant_deaths_in_total_deaths: The infant death ratio among other deaths.
# * stillbirth_total: The total number of stillbirths (dead born).
# * stillbirth_male: The total number of male stillbirths.
# * stillbirth_female: The total number of female stillbirths.
# * stillbirth_unknown_gender: The total number of unknown gender stillbirths.
# * stillbirth_rate: The stillbirth rate. Equation is stillbirth_total / (birth_total + stillbirth_total) * 1,000
# * stillbirth_gender_ratio: The stillbirth gender ratio. Equation is stillbirth_male / stillbirth_female * 1,000
# * firstborn: The number of firstborns.
# * secondborn: The number of secondborns.
# * thirdborn: The number of thirdborns.
# * forthborn: The number of forthborns.
# * fifthborn_and_above: The number of fifthborns and above.
# * weeks_under_28: The number of births occurred under week 28. Early terms.
# * weeks_28-31: The number of births occurred between weeks 28 and 31. Early terms.
# * weeks_32-36: The number of births occurred between weeks 32 and 36. Early terms.
# * weeks_37-41: The number of births occurred between weeks 37 and 41. Full terms.
# * weeks_over_42: The number of births occurred over week 42. Late terms.
# * mother_age_avg: The mother's average age.
# * mother_age_firstborn: The mother's average age of the firstborn.
# * mother_age_secondborn: The mother's average age of the secondborn.
# * mother_age_thirdborn: The mother's average age of the thirdborn.
# * mother_age_under_19: The number of births by mothers under age 19.
# * mother_age_20-24: The number of births by mothers between age 20 and 24.
# * mother_age_25-29: The number of births by mothers between age 25 and 29.
# * mother_age_30-34: The number of births by mothers between age 30 and 34.
# * mother_age_35-39: The number of births by mothers between age 35 and 39.
# * mother_age_40-44: The number of births by mothers between age 40 and 44.
# * mother_age_over_45: The number of births by mothers over 45.
# * father_age_avg: The father's average age.
# * father_age_firstborn: The father's average age of the firstborn.
# * father_age_secondborn: The father's average age of the secondborn.
# * father_age_thirdborn: The father's average age of the thirdborn.
# * legitimate_child: The Number of births under married parents.
# * illegitimate_child: The number of births under non-married parents.
#   |
# https://www.kaggle.com/datasets/webdevbadger/japan-birth-statistics

# %% [markdown]
# ## Objective

# %% [markdown]
# To examine the historical trends and fluctuations in Japan's birth rate over the years up to 2022

# %% [markdown]
# ## Snapshot

# %% [markdown]
# ![Snapshot](Data2.png)

# %%
import pandas as pd                        
import numpy as np                         
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('japan_birth.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     124 non-null    int64
#  1   year                           124 non-null    int64
#  2   birth_total                    121 non-null    float64
#  3   birth_male                     121 non-null    float64
#  4   birth_female                   121 non-null    float64
#  5   birth_rate                     121 non-null    float64
#  6   birth_gender_ratio             121 non-null    float64
#  7   total_fertility_rate           76 non-null     float64
#  8   population_total               124 non-null    int64
#  9   population_male                124 non-null    int64
#  10  population_female              124 non-null    int64
#  11  infant_death_total             121 non-null    float64
# ...

# %%
df.shape
# Out:
# (124, 51)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  year  birth_total  birth_male  birth_female  birth_rate  \
# 0             0  1899    1386981.0    713442.0      673539.0        32.0
# 1             1  1900    1420534.0    727916.0      692618.0        32.4
# 2             2  1901    1501591.0    769494.0      732097.0        33.9
# 3             3  1902    1510835.0    773296.0      737539.0        33.6
# 4             4  1903    1489816.0    763806.0      726010.0        32.7
# ..          ...   ...          ...         ...           ...         ...
# 119         119  2018     918400.0    470851.0      447549.0         7.4
# 120         120  2019     865239.0    443430.0      421809.0         7.0
# 121         121  2020     840835.0    430713.0      410122.0         6.8
# 122         122  2021     811622.0    415903.0      395719.0         6.6
# 123         123  2022     770759.0    395257.0      375502.0         6.3
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'birth_total', 'birth_male', 'birth_female',
#        'birth_rate', 'birth_gender_ratio', 'total_fertility_rate',
#        'population_total', 'population_male', 'population_female',
#        'infant_death_total', 'infant_death_male', 'infant_death_female',
#        'infant_death_unknown_gender', 'infant_death_rate',
#        'infant_death_gender_ratio', 'infant_deaths_in_total_deaths',
#        'stillbirth_total', 'stillbirth_male', 'stillbirth_female',
#        'stillbirth_unknown_gender', 'stillbirth_rate',
#        'stillbirth_gender_ratio', 'firstborn', 'secondborn', 'thirdborn',
#        'forthborn', 'fifthborn_and_above', 'weeks_under_28', 'weeks_28-31',
#        'weeks_32-36', 'weeks_37-41', 'weeks_over_42', 'mother_age_avg',
#        'mother_age_firstborn', 'mother_age_secondborn', 'mother_age_thirdborn',
#        'mother_age_under_19', 'mother_age_20-24', 'mother_age_25-29',
#        'mother_age_30-34', 'mother_age_35-39', 'mother_age_40-44',
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         year   birth_total    birth_male  birth_female  \
# count  124.000000   124.000000  1.210000e+02  1.210000e+02  1.210000e+02
# mean    61.500000  1960.500000  1.626691e+06  8.342706e+05  7.924202e+05
# std     35.939764    35.939764  4.334684e+05  2.219274e+05  2.115989e+05
# min      0.000000  1899.000000  7.707590e+05  3.952570e+05  3.755020e+05
# 25%     30.750000  1929.750000  1.221585e+06  6.269710e+05  5.946140e+05
# 50%     61.500000  1960.500000  1.659521e+06  8.502090e+05  8.069600e+05
# 75%     92.250000  1991.250000  1.990876e+06  1.017457e+06  9.680360e+05
# max    123.000000  2022.000000  2.696638e+06  1.380008e+06  1.316630e+06
#
#        birth_rate  birth_gender_ratio  total_fertility_rate  population_total  \
# count  121.000000          121.000000             76.000000      1.240000e+02
# mean    20.947107          105.312397              1.869474      9.140094e+07
# ...

# %% [markdown]
# ## Histogram

# %%
sns.histplot(df['birth_total'].dropna(), bins=12, color='lightgreen', kde=False, edgecolor='green')
plt.title('Histogram of Birth Total')
plt.xlabel('Birth Total')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['birth_total'].dropna(), bins=12, color='lightgreen', kde=True, edgecolor='green')
plt.title('Histogram of Birth Total')
plt.xlabel('Birth Total')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['birth_male'].dropna(), bins=12, color='lightgreen', kde=True, edgecolor='green')
plt.title('Histogram of Birth Total')
plt.xlabel('Birth male')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['birth_female'].dropna(), bins=12, color='lightgreen', kde=True, edgecolor='green')
plt.title('Histogram of Birth Total')
plt.xlabel('Birth male')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df["birth_total"], bins=12, log=True, edgecolor='blue')
plt.xlabel("Birth Totals (log scale)")
plt.ylabel("Number of occurrences")
plt.title("Distribution of birth totals (log scale)")
plt.show()

# %%
male_births = df["birth_male"]
female_births = df["birth_female"]
years = df["year"]
plt.plot(years, male_births, label="Male Births", marker='o')
plt.plot(years, female_births, label="Female Births", marker='s')
plt.legend()

# %%
male_births = df["birth_male"]
female_births = df["birth_female"]
years = df["year"]

plt.plot(years, male_births, label="Male Births", marker='o')
plt.plot(years, female_births, label="Female Births", marker='s')

plt.xlabel("Year")
plt.ylabel("Number of Births")
plt.title("Comparison of Male and Female Births (1899-2022)")

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
male_births = df["birth_male"]
female_births = df["birth_female"]
years = df["year"]

plt.figure(figsize=(15, 8))
plt.bar(years, male_births, label="Male Births", width=0.4, align='center')
plt.bar([p + 0.4 for p in years], female_births, label="Female Births", width=0.4, align='center')

plt.xlabel("Year")
plt.ylabel("Number of Births")
plt.title("Comparison of Male and Female Births (1899-2022)")

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=1)
plt.show()

# %% [markdown]
# ## Interpretation

# %% [markdown]
# * From the above Histogram and Bar graph we can see Japan's general birth rate trend.
# * We can observe that the above histograms are right-skewed.
# * The general trend of birth decline can be seen.
# * A prominent observation is the general decline in birth rates over the decades.
# * Specifically, there was a notable surge in births around the year 1948, followed by a subsequent decline until approximately 1960.
# * Post-1960, there is a resurgence in birth rates, peaking around 1976, after which the trend reverses, showing a continuous decline leading up to 2022.
# * Data between 1944 and 1946 is missing due to World War II.

# %% [markdown]
# Analysing the above EDA and understanding these trends can be crucial for discussions on societal changes and policy implications such as:
#
# * Aging Population: The persistent decline in birth rates contributes to an aging population, which poses challenges for healthcare, pension systems, and economic growth.
#
# * Labor Force Dynamics: A shrinking working-age population affects labor supply, potentially impacting productivity, innovation, and economic competitiveness.
#
# * Social Welfare: Policies may need adjustment to support a growing elderly population, including healthcare services, elder care facilities, and social security systems.
#
# * Family Support Policies: Enhancing policies to support families, such as affordable childcare, parental leave, and housing incentives, could potentially encourage higher birth rates.
#
# * Economic Growth: Addressing demographic shifts is critical for sustaining economic growth and ensuring long-term fiscal sustainability.
#
# * Cultural and Social Norms: Understanding the reasons behind declining birth rates involves examining cultural attitudes, gender roles, and lifestyle choices.
#
# * Immigration Policies: Given the declining native population, discussions may arise about immigration policies as a means to supplement workforce gaps and mitigate demographic decline.
